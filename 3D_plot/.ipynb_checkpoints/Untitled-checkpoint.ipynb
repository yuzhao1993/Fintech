# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('Option2017_2_Clean.csv')

# %%
k = np.linspace(df['StrikePrice'].min(), df['StrikePrice'].max(), 50)
t = np.linspace(0.25, df['Expiration Date'].max(), 50)
k, t = np.meshgrid(k, t)

implied_vol = (k - 35) ** 2 / (35 * k) / (np.power(t,0.95))

# %%
fig = plt.figure(figsize=(30,18))
ax = Axes3D(fig)
surf = ax.plot_surface(k, t, implied_vol, 
                       rstride=2, cstride=2, cmap=cm.coolwarm, lw=0.5, antialiased=False)
ax.set_xlabel('Strike Price')
ax.set_ylabel('Time to Maturity')
ax.set_zlabel('Implied Volatility')

plt.show()
