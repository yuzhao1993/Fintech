# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /Users/YU/anaconda3/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: pandas>=0.21 in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (0.24.2)
# Requirement already satisfied: lxml in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (4.3.4)
# Requirement already satisfied: requests>=2.3.0 in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: numpy>=1.12.0 in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /Users/YU/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas_datareader) (2019.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/YU/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/YU/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/YU/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/YU/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas_datareader) (2019.6.16)
# Requirement already satisfied: six>=1.5 in /Users/YU/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas>=0.21->pandas_datareader) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import time
import os
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
def retrieve_stock_data(stock_list, s_date, e_date):
    i = 0
    stock_data = {}
    for stock in stock_list:
        data = web.DataReader(stock, 'yahoo', s_date, e_date)
        stock_data[stock] = data
        filename = stock + '.csv'
        data.to_csv(filename)
        i += 1
    return stock_data

# %%
stock_list = ['WMT', 'TGT', 'JCP', 'KSS', 'HD', 'BBY', 'COST', 'AAPL', 'MSFT', 'AMZN', 'GOOG', 'FB',
              'JPM', 'BAC', 'HSBC', 'C', 'GS', 'GM', 'F', 'TM', 'TSLA', 'HMC']

# %%
dir_name = 'Stock_data'
if not os.path.isfile(dir_name):
    try:
        os.mkdir(dir_name)
    except FileExistsError:
        print("Can't create " + dir_name + "!\t")
        print("A same name folder may exist\n")

os.chdir(dir_name)
stock_data = retrieve_stock_data(stock_list, '10/01/2006', '11/04/2019')
os.chdir('..')
print("\nData retrival is complete. Check your directory**" + dir_name + "**to find your data!\n")
# Out:
# Data retrival is complete. Check your directory**Stock_data**to find your data!

# %%
years_list = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
              '2017', '2018', '2019']
for stock in stock_list:
    stock_data[stock]['PofPriceChange'] = (stock_data[stock]['Close'] - stock_data[stock]['Open']) / \
                                          stock_data[stock]['Open']
    for year in years_list:
        if year in stock_data[stock].index:
            print('Days in ' + year + ' stock price went up by 2% of ' + stock + ' is: '+str(np.sum(
                stock_data[stock]['PofPriceChange'][year] >= 0.02))+' days')
            print('Days in ' + year + ' stock price went down by 2% of ' + stock + ' is: ' + str(
                np.sum(stock_data[stock]['PofPriceChange'][year] <= -0.02)) + ' days\n')
        else:
            print(stock+' has no data in '+year+'\n')
# Out:
# Days in 2006 stock price went up by 2% of WMT is: 4 days
# Days in 2006 stock price went down by 2% of WMT is: 1 days
#
# Days in 2007 stock price went up by 2% of WMT is: 8 days
# Days in 2007 stock price went down by 2% of WMT is: 7 days
#
# Days in 2008 stock price went up by 2% of WMT is: 28 days
# Days in 2008 stock price went down by 2% of WMT is: 21 days
#
# Days in 2009 stock price went up by 2% of WMT is: 15 days
# Days in 2009 stock price went down by 2% of WMT is: 10 days
#
# Days in 2010 stock price went up by 2% of WMT is: 1 days
# Days in 2010 stock price went down by 2% of WMT is: 4 days
#
# Days in 2011 stock price went up by 2% of WMT is: 6 days
# Days in 2011 stock price went down by 2% of WMT is: 2 days
#
# Days in 2012 stock price went up by 2% of WMT is: 2 days
# Days in 2012 stock price went down by 2% of WMT is: 3 days
#
# Days in 2013 stock price went up by 2% of WMT is: 1 days
# Days in 2013 stock price went down by 2% of WMT is: 1 days
#
# Days in 2014 stock price went up by 2% of WMT is: 1 days
# Days in 2014 stock price went down by 2% of WMT is: 2 days
#
# Days in 2015 stock price went up by 2% of WMT is: 2 days
# Days in 2015 stock price went down by 2% of WMT is: 9 days
#
# Days in 2016 stock price went up by 2% of WMT is: 6 days
# Days in 2016 stock price went down by 2% of WMT is: 7 days
#
# Days in 2017 stock price went up by 2% of WMT is: 2 days
# Days in 2017 stock price went down by 2% of WMT is: 2 days
#
# Days in 2018 stock price went up by 2% of WMT is: 10 days
# Days in 2018 stock price went down by 2% of WMT is: 15 days
#
# Days in 2019 stock price went up by 2% of WMT is: 2 days
# Days in 2019 stock price went down by 2% of WMT is: 2 days
#
# Days in 2006 stock price went up by 2% of TGT is: 6 days
# Days in 2006 stock price went down by 2% of TGT is: 3 days
#
# Days in 2007 stock price went up by 2% of TGT is: 20 days
# Days in 2007 stock price went down by 2% of TGT is: 28 days
#
# Days in 2008 stock price went up by 2% of TGT is: 64 days
# Days in 2008 stock price went down by 2% of TGT is: 60 days
#
# Days in 2009 stock price went up by 2% of TGT is: 41 days
# Days in 2009 stock price went down by 2% of TGT is: 35 days
#
# Days in 2010 stock price went up by 2% of TGT is: 11 days
# Days in 2010 stock price went down by 2% of TGT is: 5 days
#
# Days in 2011 stock price went up by 2% of TGT is: 10 days
# Days in 2011 stock price went down by 2% of TGT is: 11 days
#
# Days in 2012 stock price went up by 2% of TGT is: 4 days
# Days in 2012 stock price went down by 2% of TGT is: 4 days
#
# Days in 2013 stock price went up by 2% of TGT is: 5 days
# Days in 2013 stock price went down by 2% of TGT is: 0 days
#
# Days in 2014 stock price went up by 2% of TGT is: 7 days
# Days in 2014 stock price went down by 2% of TGT is: 6 days
#
# Days in 2015 stock price went up by 2% of TGT is: 3 days
# Days in 2015 stock price went down by 2% of TGT is: 13 days
#
# Days in 2016 stock price went up by 2% of TGT is: 8 days
# Days in 2016 stock price went down by 2% of TGT is: 6 days
#
# Days in 2017 stock price went up by 2% of TGT is: 16 days
# Days in 2017 stock price went down by 2% of TGT is: 13 days
#
# Days in 2018 stock price went up by 2% of TGT is: 17 days
# Days in 2018 stock price went down by 2% of TGT is: 26 days
#
# Days in 2019 stock price went up by 2% of TGT is: 12 days
# Days in 2019 stock price went down by 2% of TGT is: 6 days
#
# Days in 2006 stock price went up by 2% of JCP is: 5 days
# Days in 2006 stock price went down by 2% of JCP is: 6 days
#
# Days in 2007 stock price went up by 2% of JCP is: 23 days
# Days in 2007 stock price went down by 2% of JCP is: 37 days
#
# Days in 2008 stock price went up by 2% of JCP is: 73 days
# Days in 2008 stock price went down by 2% of JCP is: 81 days
#
# Days in 2009 stock price went up by 2% of JCP is: 60 days
# Days in 2009 stock price went down by 2% of JCP is: 60 days
#
# Days in 2010 stock price went up by 2% of JCP is: 41 days
# Days in 2010 stock price went down by 2% of JCP is: 43 days
#
# Days in 2011 stock price went up by 2% of JCP is: 38 days
# Days in 2011 stock price went down by 2% of JCP is: 33 days
#
# Days in 2012 stock price went up by 2% of JCP is: 46 days
# Days in 2012 stock price went down by 2% of JCP is: 45 days
#
# Days in 2013 stock price went up by 2% of JCP is: 52 days
# Days in 2013 stock price went down by 2% of JCP is: 68 days
#
# Days in 2014 stock price went up by 2% of JCP is: 53 days
# Days in 2014 stock price went down by 2% of JCP is: 62 days
#
# Days in 2015 stock price went up by 2% of JCP is: 49 days
# Days in 2015 stock price went down by 2% of JCP is: 48 days
#
# Days in 2016 stock price went up by 2% of JCP is: 51 days
# Days in 2016 stock price went down by 2% of JCP is: 49 days
#
# Days in 2017 stock price went up by 2% of JCP is: 53 days
# Days in 2017 stock price went down by 2% of JCP is: 71 days
#
# Days in 2018 stock price went up by 2% of JCP is: 62 days
# Days in 2018 stock price went down by 2% of JCP is: 64 days
#
# Days in 2019 stock price went up by 2% of JCP is: 52 days
# Days in 2019 stock price went down by 2% of JCP is: 68 days
#
# Days in 2006 stock price went up by 2% of KSS is: 9 days
# Days in 2006 stock price went down by 2% of KSS is: 4 days
#
# Days in 2007 stock price went up by 2% of KSS is: 20 days
# Days in 2007 stock price went down by 2% of KSS is: 33 days
#
# Days in 2008 stock price went up by 2% of KSS is: 68 days
# Days in 2008 stock price went down by 2% of KSS is: 71 days
#
# Days in 2009 stock price went up by 2% of KSS is: 46 days
# Days in 2009 stock price went down by 2% of KSS is: 27 days
#
# Days in 2010 stock price went up by 2% of KSS is: 20 days
# Days in 2010 stock price went down by 2% of KSS is: 16 days
#
# Days in 2011 stock price went up by 2% of KSS is: 21 days
# Days in 2011 stock price went down by 2% of KSS is: 15 days
#
# Days in 2012 stock price went up by 2% of KSS is: 16 days
# Days in 2012 stock price went down by 2% of KSS is: 15 days
#
# Days in 2013 stock price went up by 2% of KSS is: 14 days
# Days in 2013 stock price went down by 2% of KSS is: 7 days
#
# Days in 2014 stock price went up by 2% of KSS is: 9 days
# Days in 2014 stock price went down by 2% of KSS is: 12 days
#
# Days in 2015 stock price went up by 2% of KSS is: 23 days
# Days in 2015 stock price went down by 2% of KSS is: 21 days
#
# Days in 2016 stock price went up by 2% of KSS is: 35 days
# Days in 2016 stock price went down by 2% of KSS is: 24 days
#
# Days in 2017 stock price went up by 2% of KSS is: 34 days
# Days in 2017 stock price went down by 2% of KSS is: 31 days
#
# Days in 2018 stock price went up by 2% of KSS is: 36 days
# Days in 2018 stock price went down by 2% of KSS is: 37 days
#
# Days in 2019 stock price went up by 2% of KSS is: 21 days
# Days in 2019 stock price went down by 2% of KSS is: 25 days
#
# Days in 2006 stock price went up by 2% of HD is: 3 days
# Days in 2006 stock price went down by 2% of HD is: 0 days
#
# Days in 2007 stock price went up by 2% of HD is: 16 days
# Days in 2007 stock price went down by 2% of HD is: 19 days
#
# Days in 2008 stock price went up by 2% of HD is: 63 days
# Days in 2008 stock price went down by 2% of HD is: 60 days
# Days in 2017 stock price went up by 2% of C is: 5 days
# Days in 2017 stock price went down by 2% of C is: 3 days
#
# Days in 2018 stock price went up by 2% of C is: 12 days
# Days in 2018 stock price went down by 2% of C is: 25 days
#
# Days in 2019 stock price went up by 2% of C is: 12 days
# Days in 2019 stock price went down by 2% of C is: 10 days
#
# Days in 2006 stock price went up by 2% of GS is: 6 days
# Days in 2006 stock price went down by 2% of GS is: 4 days
#
# Days in 2007 stock price went up by 2% of GS is: 28 days
# Days in 2007 stock price went down by 2% of GS is: 28 days
#
# Days in 2008 stock price went up by 2% of GS is: 61 days
# Days in 2008 stock price went down by 2% of GS is: 69 days
#
# Days in 2009 stock price went up by 2% of GS is: 55 days
# Days in 2009 stock price went down by 2% of GS is: 37 days
#
# Days in 2010 stock price went up by 2% of GS is: 19 days
# Days in 2010 stock price went down by 2% of GS is: 24 days
#
# Days in 2011 stock price went up by 2% of GS is: 26 days
# Days in 2011 stock price went down by 2% of GS is: 34 days
#
# Days in 2012 stock price went up by 2% of GS is: 23 days
# Days in 2012 stock price went down by 2% of GS is: 19 days
#
# Days in 2013 stock price went up by 2% of GS is: 12 days
# Days in 2013 stock price went down by 2% of GS is: 9 days
#
# Days in 2014 stock price went up by 2% of GS is: 1 days
# Days in 2014 stock price went down by 2% of GS is: 11 days
#
# Days in 2015 stock price went up by 2% of GS is: 7 days
# Days in 2015 stock price went down by 2% of GS is: 12 days
#
# Days in 2016 stock price went up by 2% of GS is: 18 days
# Days in 2016 stock price went down by 2% of GS is: 9 days
#
# Days in 2017 stock price went up by 2% of GS is: 4 days
# Days in 2017 stock price went down by 2% of GS is: 7 days
#
# Days in 2018 stock price went up by 2% of GS is: 13 days
# Days in 2018 stock price went down by 2% of GS is: 23 days
#
# Days in 2019 stock price went up by 2% of GS is: 11 days
# Days in 2019 stock price went down by 2% of GS is: 8 days
#
# GM has no data in 2006
# GM has no data in 2007
#
# GM has no data in 2008
#
# GM has no data in 2009
#
# Days in 2010 stock price went up by 2% of GM is: 1 days
# Days in 2010 stock price went down by 2% of GM is: 2 days
#
# Days in 2011 stock price went up by 2% of GM is: 28 days
# Days in 2011 stock price went down by 2% of GM is: 42 days
#
# Days in 2012 stock price went up by 2% of GM is: 32 days
# Days in 2012 stock price went down by 2% of GM is: 21 days
#
# Days in 2013 stock price went up by 2% of GM is: 15 days
# Days in 2013 stock price went down by 2% of GM is: 14 days
#
# Days in 2014 stock price went up by 2% of GM is: 12 days
# Days in 2014 stock price went down by 2% of GM is: 21 days
#
# Days in 2015 stock price went up by 2% of GM is: 8 days
# Days in 2015 stock price went down by 2% of GM is: 11 days
#
# Days in 2016 stock price went up by 2% of GM is: 16 days
# Days in 2016 stock price went down by 2% of GM is: 15 days
#
# Days in 2017 stock price went up by 2% of GM is: 9 days
# Days in 2017 stock price went down by 2% of GM is: 8 days
#
# Days in 2018 stock price went up by 2% of GM is: 15 days
# Days in 2018 stock price went down by 2% of GM is: 30 days
#
# Days in 2019 stock price went up by 2% of GM is: 10 days
IT_stock_list = stock_list[7:12]
Bank_stock_list = stock_list[12:17]
Auto_stock_list = stock_list[17:]
industry_name = ['Retail', 'IT', 'Bank', 'Auto']
industry_list = ['Retail_stock_list', 'IT_stock_list', 'Bank_stock_list', 'Auto_stock_list']

# %%
for stock in stock_list:
    for year in years_list:
        if year in stock_data[stock].index:
            print('Stock status of '+stock+' in '+year+' are:\n'+str(
                stock_data[stock]['Close'][year].describe(percentiles=[.5])[1:])+'\n')
        else:
            print(stock+' has no data in '+year+'\n')
# Out:
# Stock status of WMT in 2006 are:
# mean    47.621270
# std      1.531614
# min     45.540001
# 50%     47.650002
# max     51.750000
# Name: Close, dtype: float64
#
# Stock status of WMT in 2007 are:
# mean    46.926494
# std      1.950541
# min     42.270000
# 50%     47.619999
# max     51.209999
# Name: Close, dtype: float64
#
# Stock status of WMT in 2008 are:
# mean    55.048854
# std      3.851598
# min     45.720001
# 50%     55.950001
# max     63.169998
# Name: Close, dtype: float64
#
# Stock status of WMT in 2009 are:
# mean    50.551429
# std      2.068900
# min     46.419998
# 50%     50.055000
# max     57.180000
# Name: Close, dtype: float64
#
# Stock status of WMT in 2010 are:
# mean    53.002262
# std      1.766919
# min     48.000000
# 50%     53.580000
# max     55.990002
# Name: Close, dtype: float64
#
# Stock status of WMT in 2011 are:
# mean    54.353452
# std      2.367555
# min     48.410000
# 50%     53.879999
# max     59.990002
# Name: Close, dtype: float64
#
# Stock status of WMT in 2012 are:
# mean    67.215120
# std      6.043120
# min     57.360001
# 50%     68.265003
# max     77.150002
# Name: Close, dtype: float64
#
# Stock status of WMT in 2013 are:
# mean    75.320516
# std      3.189005
# min     68.300003
# 50%     75.750000
# max     81.209999
# Name: Close, dtype: float64
#
# Stock status of WMT in 2014 are:
# mean    77.327381
# std      3.324339
# min     72.660004
# 50%     76.439999
# max     87.540001
# Name: Close, dtype: float64
#
# Stock status of WMT in 2015 are:
# mean    72.491111
# std      9.724255
# min     56.419998
# 50%     72.735001
# max     90.470001
# Name: Close, dtype: float64
#
# Stock status of WMT in 2016 are:
# mean    69.547063
# std      2.955446
# min     60.840000
# 50%     69.810001
# max     74.300003
# Name: Close, dtype: float64
#
# Stock status of WMT in 2017 are:
# mean    78.962391
# std      8.986020
# min     65.660004
# 50%     78.150002
# max     99.620003
# Name: Close, dtype: float64
#
# Stock status of WMT in 2018 are:
# mean     92.369840
# std       6.594804
# min      82.400002
# 50%      91.519997
# max     109.550003
# Name: Close, dtype: float64
#
# Stock status of WMT in 2019 are:
# mean    106.426869
# std       8.212251
# min      92.860001
# 50%     104.764999
# max     120.239998
# Name: Close, dtype: float64
#
# Stock status of TGT in 2006 are:
# mean    58.051270
# std      0.853353
# min     55.820000
# 50%     58.070000
# max     59.750000
# Name: Close, dtype: float64
#
# Stock status of TGT in 2007 are:
# mean    61.004821
# std      3.679409
# min     50.000000
# 50%     61.360001
# max     70.139999
# Name: Close, dtype: float64
#
# Stock status of TGT in 2008 are:
# mean    47.523755
# std      7.584629
# min     26.959999
# 50%     50.490002
# max     57.889999
# Name: Close, dtype: float64
#
# Stock status of TGT in 2009 are:
# mean    41.046587
# std      6.708492
# min     25.370001
# 50%     41.214998
# max     51.349998
# Name: Close, dtype: float64
#
# Stock status of TGT in 2010 are:
# mean    53.522341
# std      2.767423
# min     48.549999
# 50%     53.475000
# max     60.259998
# Name: Close, dtype: float64
#
# Stock status of TGT in 2011 are:
# mean    51.257698
# std      2.466489
# min     46.330002
# 50%     51.070000
# max     60.770000
# Name: Close, dtype: float64
#
# Stock status of TGT in 2012 are:
# mean    58.941920
# std      4.259424
# min     48.509998
# 50%     58.584999
# max     65.440002
# Name: Close, dtype: float64
#
# Stock status of TGT in 2013 are:
# mean    66.313373
# std      3.598064
# min     58.820000
# 50%     65.704998
# max     73.320000
# Name: Close, dtype: float64
#
# Stock status of TGT in 2014 are:
# mean    61.582778
# std      4.877574
# min     55.070000
# 50%     60.495001
# max     75.910004
# Name: Close, dtype: float64
#
# Stock status of TGT in 2015 are:
# mean    78.156111
# std      3.417628
# min     69.779999
# 50%     78.310001
# max     85.010002
# Name: Close, dtype: float64
#
# Stock status of TGT in 2016 are:
# mean    73.525079
# std      5.068650
# min     66.529999
# 50%     72.500000
# max     83.980003
# Name: Close, dtype: float64
#
# Stock status of TGT in 2017 are:
# mean    58.296295
# std      4.862256
# min     50.180000
# 50%     57.299999
# max     73.809998
# Name: Close, dtype: float64
#
# Stock status of TGT in 2018 are:
# mean    76.644263
# std      6.782906
# min     61.130001
# 50%     76.139999
# max     89.260002
# Name: Close, dtype: float64
#
# Stock status of TGT in 2019 are:
# mean     86.405888
# std      14.006171
# min      65.529999
# 50%      82.590000
# max     113.680000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2006 are:
# mean    76.916666
# std      3.167033
# min     69.099998
# 50%     77.360001
# max     81.629997
# Name: Close, dtype: float64
#
# Stock status of JCP in 2007 are:
# mean    69.604741
# std     13.119353
# min     40.070000
# 50%     73.540001
# max     86.349998
# Name: Close, dtype: float64
#
# Stock status of JCP in 2008 are:
# mean    34.958261
# std      9.378174
# min     14.380000
# 50%     37.709999
# max     50.450001
# Name: Close, dtype: float64
#
# Stock status of JCP in 2009 are:
# mean    26.687064
# std      6.063426
# min     14.180000
# 50%     28.170000
# max     36.810001
# Name: Close, dtype: float64
#
# Stock status of JCP in 2010 are:
# mean    27.783214
# std      4.195174
# min     19.500000
# 50%     27.555000
# max     34.470001
# Name: Close, dtype: float64
#
# Stock status of JCP in 2011 are:
# mean    32.642381
# std      3.710367
# min     23.809999
# 50%     32.900002
# max     39.419998
# Name: Close, dtype: float64
#
# Stock status of JCP in 2012 are:
# mean    28.206640
# std      7.479189
# min     16.280001
# 50%     25.950000
# max     43.130001
# Name: Close, dtype: float64
#
# Stock status of JCP in 2013 are:
# mean    14.369484
# std      4.173244
# min      6.420000
# 50%     15.170000
# max     22.469999
# Name: Close, dtype: float64
#
# Stock status of JCP in 2014 are:
# mean     8.254087
# std      1.380680
# min      5.080000
# 50%      8.550000
# max     11.200000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2015 are:
# mean    8.408889
# std     0.779134
# min     6.290000
# 50%     8.470000
# max     9.980000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2016 are:
# mean     9.026944
# std      1.193560
# min      6.310000
# 50%      9.040000
# max     11.860000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2017 are:
# mean    4.835538
# std     1.338453
# min     2.370000
# 50%     4.710000
# max     8.470000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2018 are:
# mean    2.479960
# std     0.868697
# min     0.970000
# 50%     2.430000
# max     4.330000
# Name: Close, dtype: float64
#
# Stock status of JCP in 2019 are:
# mean    1.123458
# std     0.285439
# min     0.550000
# 50%     1.140000
# max     1.850000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2006 are:
# mean    70.776032
# std      1.748523
# min     65.489998
# 50%     70.739998
# max     73.970001
# Name: Close, dtype: float64
#
# Stock status of KSS in 2007 are:
# mean    64.525976
# std      9.727156
# min     44.950001
# 50%     67.980003
# max     78.889999
# Name: Close, dtype: float64
#
# Stock status of KSS in 2008 are:
# mean    42.086482
# std      6.334261
# min     24.980000
# 50%     43.360001
# max     53.860001
# Name: Close, dtype: float64
#
# Stock status of KSS in 2009 are:
# mean    47.328373
# std      7.457001
# min     33.580002
# 50%     45.955000
# max     60.730000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2010 are:
# mean    52.041706
# std      3.079206
# min     44.270000
# 50%     52.230000
# max     58.570000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2011 are:
# mean    51.668095
# std      3.113773
# min     42.599998
# 50%     52.244999
# max     57.000000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2012 are:
# mean    49.071240
# std      3.063450
# min     42.279999
# 50%     49.795000
# max     55.110001
# Name: Close, dtype: float64
#
# Stock status of KSS in 2013 are:
# mean    50.594802
# std      3.855157
# min     41.810001
# 50%     51.450001
# max     58.470001
# Name: Close, dtype: float64
#
# Stock status of KSS in 2014 are:
# mean    55.572143
# std      3.036148
# min     49.090000
# 50%     55.290001
# max     62.500000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2015 are:
# mean    59.862738
# std     10.878186
# min     42.849998
# 50%     61.434999
# max     79.070000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2016 are:
# mean    44.461825
# std      5.425492
# min     34.490002
# 50%     44.224998
# max     59.430000
# Name: Close, dtype: float64
#
# Stock status of KSS in 2017 are:
# mean    41.546215
# std      4.027482
# min     35.320000
# 50%     40.459999
# max     56.869999
# Name: Close, dtype: float64
#
# Stock status of KSS in 2018 are:
# mean    69.026852
# std      6.732912
# min     54.360001
# 50%     68.019997
# max     82.050003
# Name: Close, dtype: float64
#
# Stock status of KSS in 2019 are:
# mean    57.968972
# std      9.770972
# min     44.270000
# 50%     53.195000
# max     75.480003
# Name: Close, dtype: float64
#
# Stock status of HD in 2006 are:
# mean    37.866825
# std      1.183826
# min     35.759998
# 50%     37.700001
# max     40.160000
# Name: Close, dtype: float64
#
# Stock status of HD in 2007 are:
# mean    36.096175
# std      4.327046
# min     25.940001
# 50%     37.869999
# max     41.759998
# Name: Close, dtype: float64
#
# Stock status of HD in 2008 are:
# mean    25.653320
# std      2.903747
# min     18.510000
# 50%     26.280001
# max     30.639999
# Name: Close, dtype: float64
#
# Stock status of HD in 2009 are:
# mean    25.010992
# std      2.523561
# min     18.000000
# 50%     25.330000
# max     29.290001
# Name: Close, dtype: float64
#
# Stock status of HD in 2010 are:
# mean    31.216984
# std      2.471652
# min     27.070000
# 50%     31.395000
# max     36.490002
# Name: Close, dtype: float64
#
# Stock status of HD in 2011 are:
# mean    36.140952
# std      2.346408
# min     28.510000
# 50%     36.549999
# max     42.220001
# Name: Close, dtype: float64
#
# Stock status of HD in 2012 are:
# mean    53.558680
# std      6.211830
# min     42.139999
# 50%     51.955000
# max     65.070000
# Name: Close, dtype: float64
#
# Stock status of HD in 2013 are:
# mean    74.469325
# std      4.858949
# min     62.840000
# 50%     75.514999
# max     82.339996
# Name: Close, dtype: float64
#
# Stock status of HD in 2014 are:
# mean     85.428016
# std       8.155913
# min      74.970001
# 50%      81.084999
# max     104.970001
# Name: Close, dtype: float64
#
# Stock status of HD in 2015 are:
# mean    116.382460
# std       7.716028
# min     100.949997
# 50%     114.740002
# max     134.740005
# Name: Close, dtype: float64
#
# Stock status of HD in 2016 are:
# mean    129.820318
# std       5.472448
# min     111.849998
# 50%     130.055000
# max     138.770004
# Name: Close, dtype: float64
# Stock status of HD in 2017 are:
# mean    155.342749
# std      12.616358
# min     133.529999
# 50%     153.500000
# max     190.360001
# Name: Close, dtype: float64
#
# Stock status of HD in 2018 are:
# mean    188.768088
# std      11.901776
# min     158.139999
# 50%     188.000000
# max     213.850006
# Name: Close, dtype: float64
#
# Stock status of HD in 2019 are:
# mean    204.717336
# std      18.433828
# min     168.610001
# 50%     203.775002
# max     237.929993
# Name: Close, dtype: float64
#
# Stock status of BBY in 2006 are:
# mean    53.604444
# std      2.474066
# min     48.360001
# 50%     54.139999
# max     58.150002
# Name: Close, dtype: float64
#
# Stock status of BBY in 2007 are:
# mean    47.719402
# std      2.331616
# min     42.689999
# 50%     47.770000
# max     53.380001
# Name: Close, dtype: float64
#
# Stock status of BBY in 2008 are:
# mean    38.596917
# std      8.570624
# min     17.420000
# 50%     42.090000
# max     51.220001
# Name: Close, dtype: float64
#
# Stock status of BBY in 2009 are:
# mean    36.227540
# std      4.760766
# min     24.709999
# 50%     37.455000
# max     45.369999
# Name: Close, dtype: float64
#
# Stock status of BBY in 2010 are:
# mean    39.078056
# std      4.071232
# min     31.389999
# 50%     39.304998
# max     48.580002
# Name: Close, dtype: float64
#
# Stock status of BBY in 2011 are:
# mean    28.957024
# std      3.643164
# min     22.120001
# 50%     29.219999
# max     35.910000
# Name: Close, dtype: float64
#
# Stock status of BBY in 2012 are:
# mean    19.665920
# std      4.113026
# min     11.290000
# 50%     19.205000
# max     27.510000
# Name: Close, dtype: float64
#
# Stock status of BBY in 2013 are:
# mean    29.471230
# std      9.254515
# min     11.590000
# 50%     28.615001
# max     44.330002
# Name: Close, dtype: float64
#
# Stock status of BBY in 2014 are:
# mean    30.272063
# std      4.545257
# min     22.719999
# 50%     29.764999
# max     40.680000
# Name: Close, dtype: float64
#
# Stock status of BBY in 2015 are:
# mean    35.227540
# std      2.914618
# min     29.040001
# 50%     35.080000
# max     41.770000
# Name: Close, dtype: float64
#
# Stock status of BBY in 2016 are:
# mean    34.859683
# std      5.510810
# min     25.870001
# 50%     32.860001
# max     49.310001
# Name: Close, dtype: float64
#
# Stock status of BBY in 2017 are:
# mean    53.682430
# std      6.461568
# min     42.139999
# 50%     55.200001
# max     68.470001
# Name: Close, dtype: float64
#
# Stock status of BBY in 2018 are:
# mean    72.155936
# std      6.385722
# min     48.240002
# 50%     73.230003
# max     82.599998
# Name: Close, dtype: float64
#
# Stock status of BBY in 2019 are:
# mean    67.676916
# std      5.561784
# min     52.500000
# 50%     68.075001
# max     77.860001
# Name: Close, dtype: float64
#
# Stock status of COST in 2006 are:
# mean    52.605556
# std      1.289687
# min     48.750000
# 50%     52.930000
# max     54.430000
# Name: Close, dtype: float64
#
# Stock status of COST in 2007 are:
# mean    59.688287
# std      5.107529
# min     52.529999
# 50%     58.290001
# max     71.830002
# Name: Close, dtype: float64
#
# Stock status of COST in 2008 are:
# mean    63.883795
# std      7.068131
# min     44.990002
# 50%     65.820000
# max     74.660004
# Name: Close, dtype: float64
#
# Stock status of COST in 2009 are:
# mean    50.570159
# std      6.126854
# min     38.439999
# 50%     48.495001
# max     61.119999
# Name: Close, dtype: float64
#
# Stock status of COST in 2010 are:
# mean    60.669801
# std      4.469855
# min     53.610001
# 50%     59.644999
# max     72.849998
# Name: Close, dtype: float64
#
# Stock status of COST in 2011 are:
# mean    78.743294
# std      4.567840
# min     69.760002
# 50%     79.750000
# max     88.059998
# Name: Close, dtype: float64
#
# Stock status of COST in 2012 are:
# mean     92.055600
# std       6.486707
# min      79.010002
# 50%      93.715000
# max     105.949997
# Name: Close, dtype: float64
#
# Stock status of COST in 2013 are:
# mean    111.798413
# std       7.000604
# min      99.449997
# 50%     111.930000
# max     125.430000
# Name: Close, dtype: float64
#
# Stock status of COST in 2014 are:
# mean    121.582976
# std       9.592756
# min     110.180000
# 50%     117.410000
# max     144.149994
# Name: Close, dtype: float64
#
# Stock status of COST in 2015 are:
# mean    147.835357
# std       7.494194
# min     132.710007
# 50%     146.089996
# max     168.869995
# Name: Close, dtype: float64
#
# Stock status of COST in 2016 are:
# mean    154.353531
# std       6.749028
# min     141.289993
# 50%     152.235001
# max     169.039993
# Name: Close, dtype: float64
#
# Stock status of COST in 2017 are:
# mean    167.407450
# std       9.819250
# min     150.440002
# 50%     166.279999
# max     192.729996
# Name: Close, dtype: float64
#
# Stock status of COST in 2018 are:
# mean    208.814383
# std      18.189829
# min     178.610001
# 50%     207.059998
# max     244.210007
# Name: Close, dtype: float64
#
# Stock status of COST in 2019 are:
# mean    255.862383
# std      29.821058
# min     200.419998
# 50%     250.570000
# max     303.760010
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2006 are:
# mean    11.833197
# std      0.805747
# min     10.461429
# 50%     11.778571
# max     13.115714
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2007 are:
# mean    18.324843
# std      5.035107
# min     11.895715
# 50%     17.700001
# max     28.547142
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2008 are:
# mean    20.282716
# std      4.818889
# min     11.498571
# 50%     21.197144
# max     27.847143
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2009 are:
# mean    20.973447
# std      5.687273
# min     11.171429
# 50%     20.340714
# max     30.234285
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2010 are:
# mean    37.120351
# std      5.365208
# min     27.435715
# 50%     36.723572
# max     46.495716
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2011 are:
# mean    52.000618
# std      3.703407
# min     45.045715
# 50%     51.003572
# max     60.320000
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2012 are:
# mean     82.292817
# std       9.568127
# min      58.747143
# 50%      83.212856
# max     100.300003
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2013 are:
# mean    67.519269
# std      6.412542
# min     55.790001
# 50%     65.867859
# max     81.441429
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2014 are:
# mean     92.264654
# std      13.371293
# min      71.397141
# 50%      93.900002
# max     119.000000
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2015 are:
# mean    120.040000
# std       7.683550
# min     103.120003
# 50%     120.299999
# max     133.000000
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2016 are:
# mean    104.604008
# std       7.640743
# min      90.339996
# 50%     105.750000
# max     118.250000
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2017 are:
# mean    150.551075
# std      14.621191
# min     116.019997
# 50%     152.740005
# max     176.419998
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2018 are:
# mean    189.053427
# std      20.593861
# min     146.830002
# 50%     186.050003
# max     232.070007
# Name: Close, dtype: float64
#
# Stock status of AAPL in 2019 are:
# mean    197.165888
# std      23.841483
# min     142.190002
# 50%     199.620003
# max     257.500000
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2006 are:
# mean    29.009206
# std      0.762365
# min     27.360001
# 50%     29.120001
# max     30.190001
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2007 are:
# mean    30.446773
# std      2.319032
# min     26.719999
# 50%     29.930000
# max     37.060001
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2008 are:
# mean    26.647391
# std      3.846048
# min     17.530001
# 50%     27.620001
# max     35.369999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2009 are:
# mean    22.976786
# std      4.246812
# min     15.150000
# 50%     23.395000
# max     31.389999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2010 are:
# mean    27.058571
# std      2.231897
# min     23.010000
# 50%     26.825000
# max     31.389999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2011 are:
# mean    26.052341
# std      1.179666
# min     23.709999
# 50%     25.900000
# max     28.870001
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2012 are:
# mean    29.820960
# std      1.606413
# min     26.370001
# 50%     29.975000
# max     32.849998
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2013 are:
# mean    32.491905
# std      3.454846
# min     26.459999
# 50%     33.014999
# max     38.939999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2014 are:
# mean    42.453492
# std      3.901571
# min     34.980000
# 50%     41.885000
# max     49.610001
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2015 are:
# mean    46.714286
# std      4.319520
# min     40.290001
# 50%     46.230000
# max     56.549999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2016 are:
# mean    55.259325
# std      3.834578
# min     48.430000
# 50%     55.105000
# max     63.619999
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2017 are:
# mean    71.984024
# std      7.001347
# min     62.299999
# 50%     71.150002
# max     86.849998
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2018 are:
# mean    101.033984
# std       7.917807
# min      85.010002
# 50%     101.160004
# max     115.610001
# Name: Close, dtype: float64
#
# Stock status of MSFT in 2019 are:
# mean    126.585608
# std      12.759509
# min      97.400002
# 50%     130.245003
# max     144.610001
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2006 are:
# mean    37.814444
# std      3.421240
# min     30.870001
# 50%     38.770000
# max     42.959999
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2007 are:
# mean     67.229482
# std      20.470424
# min      36.430000
# 50%      71.739998
# max     100.820000
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2008 are:
# mean    69.880040
# std     12.939455
# min     35.029999
# 50%     73.949997
# max     96.250000
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2009 are:
# mean     87.281825
# std      23.795619
# min      48.439999
# 50%      82.860001
# max     142.250000
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2010 are:
# mean    139.140397
# std      20.475988
# min     108.610001
# 50%     130.719994
# max     184.759995
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2011 are:
# mean    196.672024
# std      19.166743
# min     160.970001
# 50%     193.674995
# max     246.710007
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2012 are:
# mean    220.303640
# std      25.997110
# min     175.929993
# 50%     224.044998
# max     261.679993
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2013 are:
# mean    298.031588
# std      42.014768
# min     248.229996
# 50%     281.930008
# max     404.390015
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2014 are:
# mean    332.551033
# std      27.665213
# min     287.059998
# 50%     326.425003
# max     407.049988
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2015 are:
# mean    478.138295
# std     110.745010
# min     286.950012
# 50%     439.745010
# max     693.969971
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2016 are:
# mean    699.523135
# std      92.362312
# min     482.070007
# 50%     727.875000
# max     844.359985
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2017 are:
# mean     968.167012
# std      106.580208
# min      753.669983
# 50%      967.989990
# max     1195.829956
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2018 are:
# mean    1641.726176
# std      197.275076
# min     1189.010010
# 50%     1624.890015
# max     2039.510010
# Name: Close, dtype: float64
#
# Stock status of AMZN in 2019 are:
# mean    1791.057852
# std      108.921870
# min     1500.280029
# 50%     1792.984985
# max     2020.989990
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2006 are:
# mean    232.145576
# std      13.764373
# min     199.970459
# 50%     236.613113
# max     253.873413
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2007 are:
# mean    268.369305
# std      41.163346
# min     218.520935
# 50%     254.989243
# max     369.509979
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2008 are:
# mean    231.558071
# std      50.020632
# min     128.239334
# 50%     236.005386
# max     341.385406
# Name: Close, dtype: float64
# Stock status of GOOG in 2009 are:
# mean    219.023214
# std      44.445483
# min     140.847076
# 50%     213.098755
# max     310.272034
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2010 are:
# mean    266.811472
# std      25.136143
# min     217.220810
# 50%     266.162354
# max     312.214752
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2011 are:
# mean    283.424738
# std      21.341975
# min     236.553345
# 50%     287.644333
# max     321.744019
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2012 are:
# mean    320.208021
# std      26.366805
# min     278.481171
# 50%     315.216003
# max     382.590942
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2013 are:
# mean    440.470378
# std      49.179290
# min     350.122650
# 50%     436.488937
# max     558.262512
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2014 are:
# mean    559.803290
# std      25.896532
# min     494.033630
# 50%     562.994751
# max     607.806763
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2015 are:
# mean    602.005681
# std      81.725745
# min     491.201416
# 50%     562.306427
# max     776.599976
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2016 are:
# mean    743.486707
# std      34.455758
# min     668.260010
# 50%     742.845001
# max     813.109985
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2017 are:
# mean     921.780837
# std       77.232561
# min      786.140015
# 50%      929.570007
# max     1077.140015
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2018 are:
# mean    1113.225134
# std       67.315548
# min      976.219971
# 50%     1103.979980
# max     1268.329956
# Name: Close, dtype: float64
#
# Stock status of GOOG in 2019 are:
# mean    1163.964441
# std       61.738730
# min     1016.059998
# 50%     1168.234985
# max     1292.030029
# Name: Close, dtype: float64
#
# FB has no data in 2006
#
# FB has no data in 2007
#
# FB has no data in 2008
#
# FB has no data in 2009
#
# FB has no data in 2010
#
# FB has no data in 2011
#
# Stock status of FB in 2012 are:
# mean    24.673097
# std      4.616111
# min     17.730000
# 50%     23.290001
# max     38.230000
# Name: Close, dtype: float64
#
# Stock status of FB in 2013 are:
# mean    35.481151
# std     10.621172
# min     22.900000
# 50%     29.790000
# max     57.959999
# Name: Close, dtype: float64
#
# Stock status of FB in 2014 are:
# mean    68.762341
# std      7.502259
# min     53.529999
# 50%     69.065002
# max     81.449997
# Name: Close, dtype: float64
#
# Stock status of FB in 2015 are:
# mean     88.772857
# std      10.211442
# min      74.050003
# 50%      86.790001
# max     109.010002
# Name: Close, dtype: float64
#
# Stock status of FB in 2016 are:
# mean    117.035873
# std       8.899858
# min      94.160004
# 50%     117.764999
# max     133.279999
# Name: Close, dtype: float64
#
# Stock status of FB in 2017 are:
# mean    156.576175
# std      17.379058
# min     116.860001
# 50%     153.610001
# max     183.029999
# Name: Close, dtype: float64
#
# Stock status of FB in 2018 are:
# mean    171.510956
# std      19.977452
# min     124.059998
# 50%     174.699997
# max     217.500000
# Name: Close, dtype: float64
#
# Stock status of FB in 2019 are:
# mean    178.504439
# std      15.297949
# min     131.740005
# 50%     181.634995
# max     204.869995
# Name: Close, dtype: float64
#
# Stock status of JPM in 2006 are:
# mean    47.488889
# std      0.615937
# min     46.009998
# 50%     47.529999
# max     48.950001
# Name: Close, dtype: float64
#
# Stock status of JPM in 2007 are:
# mean    47.754741
# std      2.990498
# min     40.459999
# 50%     47.990002
# max     53.200001
# Name: Close, dtype: float64
#
# Stock status of JPM in 2008 are:
# mean    39.826838
# std      5.206872
# min     22.719999
# 50%     40.490002
# max     49.849998
# Name: Close, dtype: float64
#
# Stock status of JPM in 2009 are:
# mean    35.493175
# std      7.872782
# min     15.900000
# 50%     35.970001
# max     47.160000
# Name: Close, dtype: float64
#
# Stock status of JPM in 2010 are:
# mean    40.357302
# std      2.558154
# min     35.630001
# 50%     39.885000
# max     47.810001
# Name: Close, dtype: float64
#
# Stock status of JPM in 2011 are:
# mean    39.359286
# std      5.804207
# min     28.379999
# 50%     40.674999
# max     48.000000
# Name: Close, dtype: float64
#
# Stock status of JPM in 2012 are:
# mean    39.219800
# std      3.580396
# min     31.000000
# 50%     39.309999
# max     46.270000
# Name: Close, dtype: float64
#
# Stock status of JPM in 2013 are:
# mean    51.877540
# std      3.374692
# min     44.570000
# 50%     52.240002
# max     58.480000
# Name: Close, dtype: float64
#
# Stock status of JPM in 2014 are:
# mean    58.173373
# std      2.218149
# min     53.310001
# 50%     58.164999
# max     63.150002
# Name: Close, dtype: float64
#
# Stock status of JPM in 2015 are:
# mean    63.829484
# std      3.680196
# min     54.380001
# 50%     63.994999
# max     70.080002
# Name: Close, dtype: float64
#
# Stock status of JPM in 2016 are:
# mean    65.622817
# std      7.783411
# min     53.070000
# 50%     64.040001
# max     87.129997
# Name: Close, dtype: float64
#
# Stock status of JPM in 2017 are:
# mean     92.009482
# std       6.350204
# min      82.150002
# 50%      91.150002
# max     107.830002
# Name: Close, dtype: float64
#
# Stock status of JPM in 2018 are:
# mean    110.723347
# std       4.863944
# min      92.139999
# 50%     111.110001
# max     118.769997
# Name: Close, dtype: float64
#
# Stock status of JPM in 2019 are:
# mean    110.303879
# std       6.620550
# min      97.110001
# 50%     109.840000
# max     129.100006
# Name: Close, dtype: float64
#
# Stock status of BAC in 2006 are:
# mean    53.852381
# std      0.690165
# min     51.660000
# 50%     53.810001
# max     54.900002
# Name: Close, dtype: float64
#
# Stock status of BAC in 2007 are:
# mean    49.540040
# std      3.093405
# min     41.099998
# 50%     50.410000
# max     54.049999
# Name: Close, dtype: float64
#
# Stock status of BAC in 2008 are:
# mean    30.756799
# std      8.932049
# min     11.250000
# 50%     32.900002
# max     45.029999
# Name: Close, dtype: float64
#
# Stock status of BAC in 2009 are:
# mean    12.353056
# std      4.279186
# min      3.140000
# 50%     13.020000
# max     18.590000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2010 are:
# mean    14.693254
# std      2.100194
# min     10.950000
# 50%     14.600000
# max     19.480000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2011 are:
# mean    10.027659
# std      3.348623
# min      4.990000
# 50%     10.600000
# max     15.250000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2012 are:
# mean     8.446320
# std      1.171993
# min      5.800000
# 50%      8.125000
# max     11.610000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2013 are:
# mean    13.448849
# std      1.317261
# min     11.030000
# 50%     13.495000
# max     15.880000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2014 are:
# mean    16.344444
# std      0.856921
# min     14.510000
# 50%     16.435000
# max     18.129999
# Name: Close, dtype: float64
#
# Stock status of BAC in 2015 are:
# mean    16.575714
# std      0.828268
# min     15.150000
# 50%     16.485000
# max     18.450001
# Name: Close, dtype: float64
#
# Stock status of BAC in 2016 are:
# mean    15.431905
# std      2.754263
# min     11.160000
# 50%     14.695000
# max     23.160000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2017 are:
# mean    24.723825
# std      1.919439
# min     22.049999
# 50%     24.110001
# max     29.879999
# Name: Close, dtype: float64
#
# Stock status of BAC in 2018 are:
# mean    29.695060
# std      2.002631
# min     22.730000
# 50%     30.129999
# max     32.840000
# Name: Close, dtype: float64
#
# Stock status of BAC in 2019 are:
# mean    28.808131
# std      1.388013
# min     24.559999
# 50%     28.940001
# max     32.820000
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2006 are:
# mean    93.728413
# std      2.111663
# min     90.199997
# 50%     93.980003
# max     98.410004
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2007 are:
# mean    90.744741
# std      3.420083
# min     82.540001
# 50%     91.650002
# max     99.519997
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2008 are:
# mean    74.481146
# std     11.326810
# min     45.549999
# 50%     78.290001
# max     87.669998
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2009 are:
# mean    46.293611
# std     10.463970
# min     23.590000
# 50%     45.370001
# max     63.950001
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2010 are:
# mean    51.426270
# std      2.942048
# min     44.369999
# 50%     51.720001
# max     59.320000
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2011 are:
# mean    47.623571
# std      6.504134
# min     35.830002
# 50%     49.334999
# max     58.990002
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2012 are:
# mean    45.096760
# std      3.428391
# min     38.259998
# 50%     44.485001
# max     53.070000
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2013 are:
# mean    54.812460
# std      1.420133
# min     50.680000
# 50%     54.960001
# max     58.610001
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2014 are:
# mean    51.671468
# std      1.877990
# min     46.459999
# 50%     51.635000
# max     55.959999
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2015 are:
# mean    43.339444
# std      3.436727
# min     37.040001
# 50%     43.785000
# max     50.169998
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2016 are:
# mean    34.775079
# std      3.384833
# min     29.260000
# 50%     33.705000
# max     42.959999
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2017 are:
# mean    45.564502
# std      3.635924
# min     39.730000
# 50%     46.950001
# max     51.660000
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2018 are:
# mean    46.948964
# std      4.102627
# min     38.570000
# 50%     47.500000
# max     55.619999
# Name: Close, dtype: float64
#
# Stock status of HSBC in 2019 are:
# mean    40.416869
# std      2.106617
# min     35.529999
# 50%     41.125000
# max     44.700001
# Name: Close, dtype: float64
#
# Stock status of C in 2006 are:
# mean    512.987300
# std      18.794742
# min     493.799988
# 50%     506.200012
# max     564.099976
# Name: Close, dtype: float64
#
# Stock status of C in 2007 are:
# mean    477.820318
# std      75.199426
# min     292.899994
# 50%     506.000000
# max     552.500000
# Name: Close, dtype: float64
#
# Stock status of C in 2008 are:
# mean    190.486562
# std      61.449526
# min      37.700001
# 50%     197.000000
# max     296.899994
# Name: Close, dtype: float64
# Stock status of C in 2009 are:
# mean    36.571825
# std     10.003149
# min     10.200000
# 50%     36.500000
# max     74.599998
# Name: Close, dtype: float64
#
# Stock status of C in 2010 are:
# mean    40.078968
# std      4.068996
# min     31.500000
# 50%     40.000000
# max     49.700001
# Name: Close, dtype: float64
#
# Stock status of C in 2011 are:
# mean    37.356746
# std      8.462523
# min     23.110001
# 50%     39.119999
# max     51.299999
# Name: Close, dtype: float64
#
# Stock status of C in 2012 are:
# mean    32.182680
# std      3.995780
# min     24.820000
# 50%     32.860001
# max     40.169998
# Name: Close, dtype: float64
#
# Stock status of C in 2013 are:
# mean    48.256587
# std      3.466623
# min     41.150002
# 50%     49.220001
# max     53.290001
# Name: Close, dtype: float64
#
# Stock status of C in 2014 are:
# mean    50.194008
# std      2.626746
# min     45.680000
# 50%     49.599998
# max     56.369999
# Name: Close, dtype: float64
#
# Stock status of C in 2015 are:
# mean    53.276865
# std      2.721360
# min     46.950001
# 50%     53.169998
# max     60.340000
# Name: Close, dtype: float64
#
# Stock status of C in 2016 are:
# mean    46.386111
# std      5.557762
# min     34.980000
# 50%     45.675001
# max     61.090000
# Name: Close, dtype: float64
#
# Stock status of C in 2017 are:
# mean    65.699522
# std      6.128586
# min     55.680000
# 50%     66.059998
# max     77.099998
# Name: Close, dtype: float64
#
# Stock status of C in 2018 are:
# mean    69.460518
# std      5.674493
# min     49.259998
# 50%     69.889999
# max     80.080002
# Name: Close, dtype: float64
#
# Stock status of C in 2019 are:
# mean    66.328318
# std      4.079471
# min     52.560001
# 50%     66.060001
# max     75.150002
# Name: Close, dtype: float64
#
# Stock status of GS in 2006 are:
# mean    191.477301
# std       9.000008
# min     170.690002
# 50%     193.110001
# max     205.100006
# Name: Close, dtype: float64
#
# Stock status of GS in 2007 are:
# mean    211.822709
# std      16.187531
# min     164.899994
# 50%     214.169998
# max     247.919998
# Name: Close, dtype: float64
#
# Stock status of GS in 2008 are:
# mean    152.089644
# std      42.537053
# min      52.000000
# 50%     169.630005
# max     207.779999
# Name: Close, dtype: float64
#
# Stock status of GS in 2009 are:
# mean    140.839802
# std      34.828572
# min      59.200001
# 50%     147.895004
# max     192.279999
# Name: Close, dtype: float64
#
# Stock status of GS in 2010 are:
# mean    155.168175
# std      12.439443
# min     131.080002
# 50%     154.139999
# max     184.919998
# Name: Close, dtype: float64
#
# Stock status of GS in 2011 are:
# mean    130.759246
# std      27.111086
# min      87.699997
# 50%     134.114998
# max     175.000000
# Name: Close, dtype: float64
#
# Stock status of GS in 2012 are:
# mean    110.763640
# std      10.745835
# min      91.000000
# 50%     114.385002
# max     129.720001
# Name: Close, dtype: float64
#
# Stock status of GS in 2013 are:
# mean    156.600992
# std       9.538316
# min     130.940002
# 50%     157.954994
# max     177.259995
# Name: Close, dtype: float64
#
# Stock status of GS in 2014 are:
# mean    173.396547
# std      11.394413
# min     152.720001
# 50%     171.899994
# max     196.889999
# Name: Close, dtype: float64
#
# Stock status of GS in 2015 are:
# mean    192.965992
# std      11.230525
# min     171.860001
# 50%     190.630005
# max     218.399994
# Name: Close, dtype: float64
#
# Stock status of GS in 2016 are:
# mean    169.113809
# std      25.150028
# min     139.509995
# 50%     161.330002
# max     243.089996
# Name: Close, dtype: float64
#
# Stock status of GS in 2017 are:
# mean    233.589761
# std      11.721888
# min     211.259995
# 50%     230.669998
# max     261.010010
# Name: Close, dtype: float64
#
# Stock status of GS in 2018 are:
# mean    233.092231
# std      24.790084
# min     156.350006
# 50%     234.089996
# max     273.380005
# Name: Close, dtype: float64
#
# Stock status of GS in 2019 are:
# mean    201.065701
# std      10.016515
# min     169.509995
# 50%     200.519997
# max     222.139999
# Name: Close, dtype: float64
#
# GM has no data in 2006
#
# GM has no data in 2007
#
# GM has no data in 2008
#
# GM has no data in 2009
#
# Stock status of GM in 2010 are:
# mean    34.403333
# std      0.886852
# min     33.250000
# 50%     34.195000
# max     36.860001
# Name: Close, dtype: float64
#
# Stock status of GM in 2011 are:
# mean    28.252857
# std      5.542260
# min     19.049999
# 50%     29.510000
# max     38.980000
# Name: Close, dtype: float64
#
# Stock status of GM in 2012 are:
# mean    23.485840
# std      2.229672
# min     18.799999
# 50%     24.015000
# max     28.830000
# Name: Close, dtype: float64
#
# Stock status of GM in 2013 are:
# mean    33.512381
# std      4.012744
# min     26.330000
# 50%     34.335001
# max     41.529999
# Name: Close, dtype: float64
#
# Stock status of GM in 2014 are:
# mean    34.567540
# std      2.310575
# min     29.690001
# 50%     34.494999
# max     40.950001
# Name: Close, dtype: float64
#
# Stock status of GM in 2015 are:
# mean    34.321548
# std      2.608257
# min     27.280001
# 50%     35.055000
# max     38.869999
# Name: Close, dtype: float64
#
# Stock status of GM in 2016 are:
# mean    31.325873
# std      1.966227
# min     26.900000
# 50%     31.265000
# max     37.660000
# Name: Close, dtype: float64
#
# Stock status of GM in 2017 are:
# mean    37.612032
# std      3.734077
# min     32.419998
# 50%     36.389999
# max     46.480000
# Name: Close, dtype: float64
#
# Stock status of GM in 2018 are:
# mean    37.806096
# std      3.316580
# min     30.559999
# 50%     37.599998
# max     44.849998
# Name: Close, dtype: float64
#
# Stock status of GM in 2019 are:
# mean    37.760514
# std      1.704210
# min     32.250000
# 50%     38.085001
# max     40.880001
# Name: Close, dtype: float64
#
# Stock status of F in 2006 are:
# mean    8.064921
# std     0.564726
# min     6.880000
# 50%     8.170000
# max     9.030000
# Name: Close, dtype: float64
#
# Stock status of F in 2007 are:
# mean    8.138645
# std     0.587306
# min     6.700000
# 50%     8.200000
# max     9.640000
# Name: Close, dtype: float64
#
# Stock status of F in 2008 are:
# mean    5.084625
# std     1.847947
# min     1.260000
# 50%     5.280000
# max     8.480000
# Name: Close, dtype: float64
#
# Stock status of F in 2009 are:
# mean     5.766587
# std      2.467613
# min      1.580000
# 50%      6.135000
# max     10.200000
# Name: Close, dtype: float64
#
# Stock status of F in 2010 are:
# mean    12.932262
# std      1.847253
# min      9.880000
# 50%     12.485000
# max     17.000000
# Name: Close, dtype: float64
#
# Stock status of F in 2011 are:
# mean    13.194643
# std      2.430485
# min      9.370000
# 50%     13.295000
# max     18.790001
# Name: Close, dtype: float64
#
# Stock status of F in 2012 are:
# mean    10.956800
# std      1.178194
# min      8.920000
# 50%     10.770000
# max     12.960000
# Name: Close, dtype: float64
#
# Stock status of F in 2013 are:
# mean    15.343849
# std      1.715137
# min     12.130000
# 50%     15.650000
# max     17.760000
# Name: Close, dtype: float64
#
# Stock status of F in 2014 are:
# mean    15.894405
# std      1.056846
# min     13.540000
# 50%     15.810000
# max     17.840000
# Name: Close, dtype: float64
#
# Stock status of F in 2015 are:
# mean    15.002738
# std      0.829806
# min     12.900000
# 50%     14.985000
# max     16.570000
# Name: Close, dtype: float64
#
# Stock status of F in 2016 are:
# mean    12.631032
# std      0.665771
# min     11.170000
# 50%     12.535000
# max     14.090000
# Name: Close, dtype: float64
#
# Stock status of F in 2017 are:
# mean    11.79259
# std      0.65163
# min     10.56000
# 50%     11.74000
# max     13.17000
# Name: Close, dtype: float64
#
# Stock status of F in 2018 are:
# mean    10.40741
# std      1.20495
# min      7.63000
# 50%     10.61000
# max     13.23000
# Name: Close, dtype: float64
#
# Stock status of F in 2019 are:
# mean     9.262850
# std      0.645316
# min      7.780000
# 50%      9.165000
# max     10.510000
# Name: Close, dtype: float64
#
# Stock status of TM in 2006 are:
# mean    120.635238
# std       5.490769
# min     110.500000
# 50%     119.730003
# max     134.309998
# Name: Close, dtype: float64
#
# Stock status of TM in 2007 are:
# mean    121.078048
# std       8.582701
# min     105.190002
# 50%     121.529999
# max     137.770004
# Name: Close, dtype: float64
#
# Stock status of TM in 2008 are:
# mean     90.413636
# std      15.558202
# min      58.169998
# 50%      93.190002
# max     116.000000
# Name: Close, dtype: float64
#
# Stock status of TM in 2009 are:
# mean    76.050278
# std      7.589575
# min     57.680000
# 50%     77.725002
# max     87.430000
# Name: Close, dtype: float64
#
# Stock status of TM in 2010 are:
# mean    75.067500
# std      4.913088
# min     67.839996
# 50%     74.044998
# max     91.779999
# Name: Close, dtype: float64
#
# Stock status of TM in 2011 are:
# mean    76.704325
# std      8.338615
# min     60.389999
# 50%     79.505001
# max     93.680000
# Name: Close, dtype: float64
#
# Stock status of TM in 2012 are:
# mean    79.816000
# std      4.801136
# min     67.639999
# 50%     80.195000
# max     93.250000
# Name: Close, dtype: float64
#
# Stock status of TM in 2013 are:
# mean    117.786944
# std      11.480983
# min      93.930000
# 50%     121.645000
# max     134.330002
# Name: Close, dtype: float64
# Stock status of TM in 2014 are:
# mean    116.213135
# std       5.104166
# min     103.389999
# 50%     116.430000
# max     129.029999
# Name: Close, dtype: float64
#
# Stock status of TM in 2015 are:
# mean    130.025080
# std       7.512153
# min     113.370003
# 50%     130.985001
# max     145.320007
# Name: Close, dtype: float64
#
# Stock status of TM in 2016 are:
# mean    111.025000
# std       6.899565
# min      98.269997
# 50%     111.165001
# max     123.070000
# Name: Close, dtype: float64
#
# Stock status of TM in 2017 are:
# mean    114.916414
# std       6.981831
# min     103.820000
# 50%     113.279999
# max     128.320007
# Name: Close, dtype: float64
#
# Stock status of TM in 2018 are:
# mean    127.655179
# std       7.066652
# min     111.809998
# 50%     128.570007
# max     140.720001
# Name: Close, dtype: float64
#
# Stock status of TM in 2019 are:
# mean    126.075608
# std       6.308257
# min     114.650002
# 50%     124.439999
# max     140.740005
# Name: Close, dtype: float64
#
# TSLA has no data in 2006
#
# TSLA has no data in 2007
#
# TSLA has no data in 2008
#
# TSLA has no data in 2009
#
# Stock status of TSLA in 2010 are:
# mean    23.341846
# std      5.081547
# min     15.800000
# 50%     20.945001
# max     35.470001
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2011 are:
# mean    26.804762
# std      2.853630
# min     21.830000
# 50%     26.900001
# max     34.939999
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2012 are:
# mean    31.168600
# std      2.729142
# min     22.790001
# 50%     31.160000
# max     38.009998
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2013 are:
# mean    104.401230
# std      53.026671
# min      32.910000
# 50%     116.209999
# max     193.369995
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2014 are:
# mean    223.329088
# std      29.298150
# min     139.339996
# 50%     224.715004
# max     286.040009
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2015 are:
# mean    230.042898
# std      23.770247
# min     185.000000
# 50%     230.404999
# max     282.260010
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2016 are:
# mean    209.767262
# std      21.369476
# min     143.669998
# 50%     208.705002
# max     265.420013
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2017 are:
# mean    314.316295
# std      40.966316
# min     216.990005
# 50%     317.549988
# max     385.000000
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2018 are:
# mean    317.309921
# std      28.760221
# min     250.559998
# 50%     318.869995
# max     379.570007
# Name: Close, dtype: float64
#
# Stock status of TSLA in 2019 are:
# mean    257.850560
# std      38.512510
# min     178.970001
# 50%     247.365005
# max     347.309998
# Name: Close, dtype: float64
#
# Stock status of HMC in 2006 are:
# mean    35.643016
# std      1.334381
# min     34.230000
# 50%     35.259998
# max     39.840000
# Name: Close, dtype: float64
#
# Stock status of HMC in 2007 are:
# mean    35.246096
# std      2.083196
# min     31.790001
# 50%     34.820000
# max     40.779999
# Name: Close, dtype: float64
#
# Stock status of HMC in 2008 are:
# mean    29.313004
# std      4.673640
# min     18.190001
# 50%     30.940001
# max     36.259998
# Name: Close, dtype: float64
#
# Stock status of HMC in 2009 are:
# mean    28.501905
# std      3.644893
# min     20.730000
# 50%     29.085000
# max     34.349998
# Name: Close, dtype: float64
#
# Stock status of HMC in 2010 are:
# mean    34.197143
# std      2.623455
# min     28.590000
# 50%     34.590000
# max     39.580002
# Name: Close, dtype: float64
#
# Stock status of HMC in 2011 are:
# mean    35.717976
# std      4.774292
# min     27.610001
# 50%     36.815001
# max     44.490002
# Name: Close, dtype: float64
#
# Stock status of HMC in 2012 are:
# mean    33.695680
# std      2.449282
# min     29.360001
# 50%     33.135000
# max     39.200001
# Name: Close, dtype: float64
#
# Stock status of HMC in 2013 are:
# mean    38.905436
# std      1.512902
# min     35.439999
# 50%     38.710001
# max     42.700001
# Name: Close, dtype: float64
#
# Stock status of HMC in 2014 are:
# mean    34.271151
# std      2.482787
# min     28.870001
# 50%     34.400002
# max     40.840000
# Name: Close, dtype: float64
#
# Stock status of HMC in 2015 are:
# mean    32.669762
# std      1.513927
# min     28.820000
# 50%     32.670000
# max     36.360001
# Name: Close, dtype: float64
#
# Stock status of HMC in 2016 are:
# mean    28.087698
# std      1.624785
# min     24.480000
# 50%     28.040000
# max     30.990000
# Name: Close, dtype: float64
#
# Stock status of HMC in 2017 are:
# mean    29.909163
# std      1.999930
# min     27.190001
# 50%     29.850000
# max     34.400002
# Name: Close, dtype: float64
#
# Stock status of HMC in 2018 are:
# mean    31.376653
# std      3.097018
# min     25.469999
# 50%     30.650000
# max     36.730000
# Name: Close, dtype: float64
#
# Stock status of HMC in 2019 are:
# mean    26.609860
# std      1.590248
# min     22.900000
# 50%     26.650000
# max     30.070000
# Name: Close, dtype: float64

# %%
def group():
    for stock in stock_list:
        df = []
        labels = []
        group = stock_data[stock].index.year.unique()
        for x in group:
            a = stock_data[stock].Close[stock_data[stock].index.year == x]
            df.append(a)
            labels.append(x)
        plt.boxplot(df, labels=labels)
        plt.xlabel(stock)
        plt.ylabel('Stock Close Price')
        plt.title('Stock Status')
        plt.grid('on')
        plt.xticks(rotation=45)
        plt.show()
group()

# %%
def plot_stock(list, df_column, xlabel, ylabel):
    for i in range(len(list)):
        plt.plot(stock_data[list[i]][df_column], label=list[i], lw=1.5)
        plt.setp(plt.gca().get_xticklabels(), FontSize=8, rotation=45)
        plt.legend(loc='upper left')
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.grid('on')

        
fig_stock_price = plt.figure(figsize=(13,7))
plt.subplot(221)
plot_stock(Retail_stock_list, 'Close', 'Stock Close Price', 'Retail industry stocks')
plt.subplot(222)
plot_stock(IT_stock_list, 'Close', 'Stock Close Price', 'IT industry stocks')
plt.subplot(223)
plot_stock(Bank_stock_list, 'Close', 'Stock Close Price', 'Bank industry stocks')
plt.subplot(224)
plot_stock(Auto_stock_list, 'Close', 'Stock Close Price', 'Auto industry stocks')
plt.tight_layout()
plt.show()

# %%
def compute_volatility(df, window_size):
    s_i = df
    s_i_minus_1 = df.shift(1)
    U_sequence = np.log(s_i / s_i_minus_1)
    ans = U_sequence.rolling(window = window_size, center = False).std() * np.sqrt(window_size)
    return ans


for stock in stock_list:
    stock_data[stock]['Volatility'] = compute_volatility(stock_data[stock]['Close'], 252)

fig_stock_volatility = plt.figure(figsize=(13,7))
plt.subplot(221)
plot_stock(Retail_stock_list, 'Volatility', 'Stock Close Price', 'Retail industry stocks')
plt.subplot(222)
plot_stock(IT_stock_list, 'Volatility', 'Stock Close Price', 'IT industry stocks')
plt.subplot(223)
plot_stock(Bank_stock_list, 'Volatility', 'Stock Close Price', 'Bank industry stocks')
plt.subplot(224)
plot_stock(Auto_stock_list, 'Volatility', 'Stock Close Price', 'Auto industry stocks')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Volatility
# 1. All stock in end of 2009 had high volatility, which mean they were more risky in that periord, especially bank industry.
# 2. In retail industry, JCP is very risky right now. Other stocks are performing well.
# 3. In IT industry, FB had very high volatility at begaining, then it drop to industry average.
# 4. In bank industry, all stocks are decrecing from 2013.
# 5. In Auto industy, TSLA is a outlier of those five stocks. It keeps high volatility all the time.

# %%
def compute_VCR(df):
    s = np.linalg.svd(df, compute_uv=False)
    rate = s[0]/np.sum(s)
    return rate


VCR = {}
for stock in stock_list:
    df = stock_data[stock].iloc[:, 2:7]
    VCR[stock] = compute_VCR(df)

def plot_VCR(s, e, color, xlabel):
    keys = list(VCR.keys())
    vals = list(VCR.values())
    plt.plot(keys[s:e], vals[s:e], color, lw=1.5, marker='s')
    plt.xlabel(xlabel)
    plt.ylabel('Variance concentration ratio')
    plt.grid(True, alpha=0.7, linestyle=':', linewidth=0.5, color='#808080')


fig_VCR = plt.figure(figsize=(13, 7))

plt.subplot(211)
plot_VCR(0, 23, '#000000', 'All Stock')
plt.subplot(245)
plot_VCR(0, 7, '#00FFFF', 'Retail industry stocks')
plt.subplot(246)
plot_VCR(7, 12, '#FF1493', 'IT industry stocks')
plt.subplot(247)
plot_VCR(12, 17, '#7CFC00', 'Bank industry stocks')
plt.subplot(248)
plot_VCR(17, 23, '#191970', 'Auto industry stocks')
fig_VCR.suptitle('Stock Variance Concentration Ratio')
fig_VCR.subplots_adjust(top=0.6)
plt.tight_layout()
plt.show()

# %%
S_ratio = {}
for stock in stock_list:
    stock_data[stock]['Log return'] = np.log(stock_data[stock]['Close']) - np.log(stock_data[stock]['Close'].shift(1))
    S_ratio[stock] = ((stock_data[stock]['Log return']*252*5*100).mean()-3)/(stock_data[stock]['Log return']*252*5*100).std()

    
def plot_s_ratio(start, end, color, xlabel):
    keys = list(S_ratio.keys())
    vals = list(S_ratio.values())
    plt.plot(keys[start:end], vals[start:end], color, lw=1.5, marker='s')
    plt.xlabel(xlabel)
    plt.ylabel('Sharpe Ratio')
    plt.grid(True, alpha=0.7, linestyle=':', linewidth=0.5, color='#808080')


fig_S_ratio = plt.figure(figsize=(13, 7))

plt.subplot(211)
plot_s_ratio(0, 23, 'r', 'All Stock')
plt.subplot(245)
plot_s_ratio(0, 7, '#00FFFF', 'Retail industry stocks')
plt.subplot(246)
plot_s_ratio(7, 12, '#FF1493', 'IT industry stocks')
plt.subplot(247)
plot_s_ratio(12, 17, '#7CFC00', 'Bank industry stocks')
plt.subplot(248)
plot_s_ratio(17, 23, '#191970', 'Auto industry stocks')
fig_S_ratio.suptitle('Stock Sharpe Ratio')
fig_S_ratio.subplots_adjust(top=0.3)
plt.tight_layout()
plt.show()

# %%
def compute_distribution(df):
    s = np.linalg.svd(df, compute_uv=False)
    rate = s/np.sum(s)
    return rate

def relative_entropy(p,q):
    if not(p.shape == q.shape):
        print("\n Error: dimension must be aligned for two vectors\n")
        quit()
    p_over_q = np.zeros(len(p))
    with np.errstate(divide='ignore'):
        p_over_q = p/q
    t = np.log2(p_over_q)
    t[np.isnan(t)] = 0.0
    t[np.isinf(t)] = 0.0
    ans = np.inner(p,t)
    return ans

p_distribution = {}
for stock in stock_list:
    df = stock_data[stock].iloc[:, 2:7]
    p_distribution[stock] = compute_distribution(df)
    
relative_entropy_matrix = np.zeros([len(p_distribution),len(p_distribution)])
for i in range(len(stock_list)):
    for j in range(len(stock_list)):
        relative_entropy_matrix[i,j] = relative_entropy(p_distribution[stock_list[i]], p_distribution[stock_list[j]])
relative_entropy_df = pd.DataFrame(data=relative_entropy_matrix, index= stock_list, columns= stock_list)
print(relative_entropy_df)
# Out:
#                WMT           TGT           JCP           KSS            HD  \
# WMT   0.000000e+00  8.670166e-07  1.789117e-06  2.496652e-06  3.578446e-06
# TGT   1.010048e-06  0.000000e+00  6.048644e-06  4.854105e-07  1.400874e-06
# JCP   1.390161e-06  4.055194e-06  0.000000e+00  6.773650e-06  8.262944e-06
# KSS   3.214977e-06  5.371808e-07  1.109921e-05  0.000000e+00  9.745190e-07
# HD    4.677430e-06  1.543965e-06  1.348005e-05  7.633849e-07  0.000000e+00
# BBY   2.747478e-07  2.143900e-07  3.644301e-06  1.275891e-06  2.379938e-06
# COST  8.521827e-05  6.134148e-05  1.303988e-04  4.801277e-05  4.096898e-05
# AAPL  4.234045e-06  7.947709e-06  1.033951e-06  1.130113e-05  1.314088e-05
# MSFT  3.547973e-06  7.078686e-06  6.664391e-07  1.032129e-05  1.210802e-05
# AMZN  5.489788e-04  4.620800e-04  7.058684e-04  4.108863e-04  3.728355e-04
# GOOG  4.651658e-04  3.885102e-04  6.039488e-04  3.434893e-04  3.094805e-04
# FB    6.946032e-07  2.808330e-06  3.310355e-07  5.199745e-06  6.301539e-06
# JPM   1.639369e-06  4.438833e-06  3.513960e-08  7.238064e-06  8.851755e-06
